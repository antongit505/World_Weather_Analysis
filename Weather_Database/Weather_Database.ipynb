# %%
#Import dependencies needed
import numpy as np
import pandas as pd
import random
from citipy import citipy
import requests

# %%
#Create a new set of 2,000 latitudes and longitudes
lats=np.random.uniform(-90,90,size=2000)
lngs=np.random.uniform(-180,180,size=2000)

#Zip the latitudes and longitudes to pair them with the same index
lats_lngs=zip(lats,lngs)

# %%
#Retrieve the city name and add them to a list if not existing
coordinates=list(lats_lngs)
cities=[]

for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 760

# %%
#Perform an API call with OpenWeatherMap and retrieve the required information
from config import weather_api_key
import time

set_count=1
record_count=1
city_data=[]

for i,city in enumerate(cities):
    
    #Create URL
    url= "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid="+str(weather_api_key)
    query_url= url+ "&q="+ city.replace(" ","+")
    
    #Processing URL 
    print(f"Processing record {record_count} ,set {set_count}|{city}")
    record_count+=1
    
    if (i%50==0 and i>=50):
        set_count+=1
        record_count=1
        time.sleep(60)
    
    try:
            
        #Parse the JSON and retrieve data
        city_weather=requests.get(query_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing record 1 ,set 1|ribeira grande
# Processing record 2 ,set 1|halifax
# Processing record 3 ,set 1|rikitea
# Processing record 4 ,set 1|shingu
# Processing record 5 ,set 1|viedma
# Processing record 6 ,set 1|radcliff
# Processing record 7 ,set 1|csenger
# Processing record 8 ,set 1|jalu
# Processing record 9 ,set 1|bluff
# Processing record 10 ,set 1|seoul
# Processing record 11 ,set 1|jagtial
# Processing record 12 ,set 1|ushuaia
# Processing record 13 ,set 1|upernavik
# Processing record 14 ,set 1|souillac
# Processing record 15 ,set 1|maitum
# Processing record 16 ,set 1|faanui
# Processing record 17 ,set 1|hermanus
# Processing record 18 ,set 1|orasac
# Processing record 19 ,set 1|albany
# Processing record 20 ,set 1|lebu
# Processing record 21 ,set 1|illoqqortoormiut
# City not found. Skipping...
# Processing record 22 ,set 1|east london
# Processing record 23 ,set 1|cravo norte
# Processing record 24 ,set 1|punta arenas
# Processing record 25 ,set 1|paamiut
# Processing record 26 ,set 1|vaini
# Processing record 27 ,set 1|rundu
# Processing record 28 ,set 1|nikolskoye
# Processing record 29 ,set 1|bathsheba
# Processing record 30 ,set 1|port-gentil
# Processing record 31 ,set 1|puerto ayora
# Processing record 32 ,set 1|busselton
# Processing record 33 ,set 1|husavik
# Processing record 34 ,set 1|hilo
# Processing record 35 ,set 1|codrington
# Processing record 36 ,set 1|nowy sacz
# Processing record 37 ,set 1|kalispell
# Processing record 38 ,set 1|fortuna
# Processing record 39 ,set 1|cape town
# Processing record 40 ,set 1|dunedin
# Processing record 41 ,set 1|barrow
# Processing record 42 ,set 1|laguna
# Processing record 43 ,set 1|khatanga
# Processing record 44 ,set 1|tigil
# Processing record 45 ,set 1|potiskum
# Processing record 46 ,set 1|taolanaro
# City not found. Skipping...
# Processing record 47 ,set 1|hobart
# Processing record 48 ,set 1|yellowknife
# Processing record 49 ,set 1|belushya guba
# City not found. Skipping...
# Processing record 50 ,set 1|kapaa
# Processing record 51 ,set 1|mutsamudu
# City not found. Skipping...
# Processing record 1 ,set 2|tuktoyaktuk
# Processing record 2 ,set 2|kamogawa
# Processing record 3 ,set 2|broken hill
# Processing record 4 ,set 2|antofagasta
# Processing record 5 ,set 2|new norfolk
# Processing record 6 ,set 2|longyearbyen
# Processing record 7 ,set 2|jamestown
# Processing record 8 ,set 2|bilma
# Processing record 9 ,set 2|tuatapere
# Processing record 10 ,set 2|aklavik
# Processing record 11 ,set 2|mahebourg
# Processing record 12 ,set 2|nanortalik
# Processing record 13 ,set 2|jasper
# Processing record 14 ,set 2|samalaeulu
# City not found. Skipping...
# Processing record 15 ,set 2|tsihombe
# City not found. Skipping...
# Processing record 16 ,set 2|kannur
# Processing record 17 ,set 2|the valley
# Processing record 18 ,set 2|arraial do cabo
# Processing record 19 ,set 2|ayan
# Processing record 20 ,set 2|tongren
# Processing record 21 ,set 2|kodiak
# Processing record 22 ,set 2|sterling
# Processing record 23 ,set 2|ust-tsilma
# Processing record 24 ,set 2|suez
# Processing record 25 ,set 2|navrongo
# Processing record 26 ,set 2|nantucket
# Processing record 27 ,set 2|fairbanks
# Processing record 28 ,set 2|suntar
# Processing record 29 ,set 2|narsaq
# Processing record 30 ,set 2|carnarvon
# Processing record 31 ,set 2|muravlenko
# Processing record 32 ,set 2|mataura
# Processing record 33 ,set 2|lompoc
# Processing record 34 ,set 2|qaanaaq
# Processing record 35 ,set 2|palmer
# Processing record 36 ,set 2|canandaigua
# Processing record 37 ,set 2|diamantino
# Processing record 38 ,set 2|avarua
# Processing record 39 ,set 2|pangody
# Processing record 40 ,set 2|semey
# Processing record 41 ,set 2|vaxjo
# Processing record 42 ,set 2|santiago del estero
# Processing record 43 ,set 2|kenora
# Processing record 44 ,set 2|esperance
# Processing record 45 ,set 2|miri
# Processing record 46 ,set 2|klaksvik
# Processing record 47 ,set 2|kaitangata
# Processing record 48 ,set 2|geylegphug
# City not found. Skipping...
# Processing record 49 ,set 2|srednekolymsk
# Processing record 50 ,set 2|valparaiso
# Processing record 1 ,set 3|obluche
# City not found. Skipping...
# Processing record 2 ,set 3|forbes
# Processing record 3 ,set 3|biak
# Processing record 4 ,set 3|srandakan
# Processing record 5 ,set 3|cabo san lucas
# Processing record 6 ,set 3|nabul
# City not found. Skipping...
# Processing record 7 ,set 3|barentsburg
# City not found. Skipping...
# Processing record 8 ,set 3|calvinia
# Processing record 9 ,set 3|maldonado
# Processing record 10 ,set 3|karpuninskiy
# City not found. Skipping...
# Processing record 11 ,set 3|dubenskiy
# City not found. Skipping...
# Processing record 12 ,set 3|marsa matruh
# Processing record 13 ,set 3|joshimath
# Processing record 14 ,set 3|mabaruma
# Processing record 15 ,set 3|airai
# Processing record 16 ,set 3|bengkulu
# Processing record 17 ,set 3|saleaula
# City not found. Skipping...
# Processing record 18 ,set 3|geraldton
# Processing record 19 ,set 3|boa vista
# Processing record 20 ,set 3|prado
# Processing record 21 ,set 3|saint-philippe
# Processing record 22 ,set 3|sao joao da barra
# Processing record 23 ,set 3|deputatskiy
# Processing record 24 ,set 3|lorengau
# Processing record 25 ,set 3|dikson
# Processing record 26 ,set 3|zhanakorgan
# Processing record 27 ,set 3|oxford
# Processing record 28 ,set 3|ilulissat
# Processing record 29 ,set 3|rawannawi
# City not found. Skipping...
# Processing record 30 ,set 3|kati
# Processing record 31 ,set 3|sakaiminato
# Processing record 32 ,set 3|trincomalee
# Processing record 33 ,set 3|ballina
# Processing record 34 ,set 3|palabuhanratu
# City not found. Skipping...
# Processing record 35 ,set 3|opuwo
# Processing record 36 ,set 3|sao jose da coroa grande
# Processing record 37 ,set 3|salalah
# Processing record 38 ,set 3|shache
# Processing record 39 ,set 3|nuuk
# Processing record 40 ,set 3|katsuura
# Processing record 41 ,set 3|novoilinsk
# Processing record 42 ,set 3|muisne
# Processing record 43 ,set 3|barhi
# Processing record 44 ,set 3|qabis
# City not found. Skipping...
# Processing record 45 ,set 3|hope
# Processing record 46 ,set 3|ambilobe
# Processing record 47 ,set 3|atuona
# Processing record 48 ,set 3|phatthalung
# Processing record 49 ,set 3|elko
# Processing record 50 ,set 3|sibolga
# Processing record 1 ,set 4|saint george
# Processing record 2 ,set 4|tiksi
# Processing record 3 ,set 4|san jeronimo
# Processing record 4 ,set 4|poum
# Processing record 5 ,set 4|satitoa
# City not found. Skipping...
# Processing record 6 ,set 4|chuy
# Processing record 7 ,set 4|cidreira
# Processing record 8 ,set 4|makariv
# Processing record 9 ,set 4|kunigal
# Processing record 10 ,set 4|petropavlovsk-kamchatskiy
# Processing record 11 ,set 4|independencia
# Processing record 12 ,set 4|aranos
# Processing record 13 ,set 4|carutapera
# Processing record 14 ,set 4|atbasar
# Processing record 15 ,set 4|turayf
# Processing record 16 ,set 4|vila velha
# Processing record 17 ,set 4|vostok
# Processing record 18 ,set 4|iranshahr
# Processing record 19 ,set 4|bethel
# Processing record 20 ,set 4|sulzbach-rosenberg
# Processing record 21 ,set 4|meulaboh
# Processing record 22 ,set 4|saskylakh
# Processing record 23 ,set 4|santa cruz
# Processing record 24 ,set 4|pueblo nuevo
# Processing record 25 ,set 4|sioux lookout
# Processing record 26 ,set 4|pangnirtung
# Processing record 27 ,set 4|krasnopillya
# Processing record 28 ,set 4|mys shmidta
# City not found. Skipping...
# Processing record 29 ,set 4|severo-kurilsk
# Processing record 30 ,set 4|port alfred
# Processing record 31 ,set 4|oeiras
# Processing record 32 ,set 4|meadow lake
# Processing record 33 ,set 4|bambous virieux
# Processing record 34 ,set 4|torbay
# Processing record 35 ,set 4|dingle
# Processing record 36 ,set 4|kralendijk
# Processing record 37 ,set 4|hampstead
# Processing record 38 ,set 4|lagoa
# Processing record 39 ,set 4|talcahuano
# Processing record 40 ,set 4|arlit
# Processing record 41 ,set 4|kavieng
# Processing record 42 ,set 4|aitape
# Processing record 43 ,set 4|port elizabeth
# Processing record 44 ,set 4|sataua
# City not found. Skipping...
# Processing record 45 ,set 4|haines junction
# Processing record 46 ,set 4|fukue
# Processing record 47 ,set 4|port shepstone
# Processing record 48 ,set 4|redmond
# Processing record 49 ,set 4|bilibino
# Processing record 50 ,set 4|dzhusaly
# City not found. Skipping...
# Processing record 1 ,set 5|provideniya
# Processing record 2 ,set 5|auki
# Processing record 3 ,set 5|attawapiskat
# City not found. Skipping...
# Processing record 4 ,set 5|puerto asis
# Processing record 5 ,set 5|plymouth
# Processing record 6 ,set 5|sarakhs
# Processing record 7 ,set 5|pirayu
# Processing record 8 ,set 5|luderitz
# Processing record 9 ,set 5|puerto varas
# Processing record 10 ,set 5|sinnamary
# Processing record 11 ,set 5|khash
# Processing record 12 ,set 5|pacific grove
# Processing record 13 ,set 5|mildura
# Processing record 14 ,set 5|talnakh
# Processing record 15 ,set 5|umzimvubu
# City not found. Skipping...
# Processing record 16 ,set 5|guerrero negro
# Processing record 17 ,set 5|gorno-chuyskiy
# City not found. Skipping...
# Processing record 18 ,set 5|bonavista
# Processing record 19 ,set 5|aykhal
# Processing record 20 ,set 5|malakal
# Processing record 21 ,set 5|mar del plata
# Processing record 22 ,set 5|gonzalez
# Processing record 23 ,set 5|campo maior
# Processing record 24 ,set 5|montepuez
# Processing record 25 ,set 5|butaritari
# Processing record 26 ,set 5|harrisonburg
# Processing record 27 ,set 5|taoudenni
# Processing record 28 ,set 5|aripuana
# Processing record 29 ,set 5|broome
# Processing record 30 ,set 5|shiyan
# Processing record 31 ,set 5|chapais
# Processing record 32 ,set 5|omboue
# Processing record 33 ,set 5|thompson
# Processing record 34 ,set 5|gurgan
# City not found. Skipping...
# Processing record 35 ,set 5|sao filipe
# Processing record 36 ,set 5|cockburn town
# Processing record 37 ,set 5|kalomo
# City not found. Skipping...
# Processing record 38 ,set 5|hamilton
# Processing record 39 ,set 5|sorland
# Processing record 40 ,set 5|minuri
# Processing record 41 ,set 5|tumannyy
# City not found. Skipping...
# Processing record 42 ,set 5|faya
# Processing record 43 ,set 5|ust-ilimsk
# Processing record 44 ,set 5|cayenne
# Processing record 45 ,set 5|ankara
# Processing record 46 ,set 5|vanavara
# Processing record 47 ,set 5|uusikaupunki
# Processing record 48 ,set 5|narimanov
# Processing record 49 ,set 5|vestmannaeyjar
# Processing record 50 ,set 5|usinsk
# Processing record 1 ,set 6|sorvag
# City not found. Skipping...
# Processing record 2 ,set 6|macau
# Processing record 3 ,set 6|rungata
# City not found. Skipping...
# Processing record 4 ,set 6|namatanai
# Processing record 5 ,set 6|vanderhoof
# Processing record 6 ,set 6|kutum
# Processing record 7 ,set 6|pastavy
# Processing record 8 ,set 6|kaeo
# Processing record 9 ,set 6|aksarka
# Processing record 10 ,set 6|kharp
# Processing record 11 ,set 6|aguimes
# Processing record 12 ,set 6|chimbote
# Processing record 13 ,set 6|mount gambier
# Processing record 14 ,set 6|moyale
# Processing record 15 ,set 6|ponta do sol
# Processing record 16 ,set 6|sivaki
# Processing record 17 ,set 6|kyabe
# Processing record 18 ,set 6|beitbridge
# Processing record 19 ,set 6|shimanovsk
# Processing record 20 ,set 6|victoria
# Processing record 21 ,set 6|kyaikto
# Processing record 22 ,set 6|castro
# Processing record 23 ,set 6|grand river south east
# City not found. Skipping...
# Processing record 24 ,set 6|atar
# Processing record 25 ,set 6|sebinkarahisar
# Processing record 26 ,set 6|oistins
# Processing record 27 ,set 6|puerto leguizamo
# Processing record 28 ,set 6|yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing record 29 ,set 6|sabang
# Processing record 30 ,set 6|amarante do maranhao
# Processing record 31 ,set 6|vidim
# Processing record 32 ,set 6|georgetown
# Processing record 33 ,set 6|alvand
# Processing record 34 ,set 6|clyde river
# Processing record 35 ,set 6|cherskiy
# Processing record 36 ,set 6|bredasdorp
# Processing record 37 ,set 6|tombouctou
# Processing record 38 ,set 6|benjamin hill
# Processing record 39 ,set 6|bandarbeyla
# Processing record 40 ,set 6|bridlington
# Processing record 41 ,set 6|vaitupu
# City not found. Skipping...
# Processing record 42 ,set 6|fords
# Processing record 43 ,set 6|lavrentiya
# Processing record 44 ,set 6|ketchikan
# Processing record 45 ,set 6|jiddah
# City not found. Skipping...
# Processing record 46 ,set 6|yatou
# Processing record 47 ,set 6|edd
# Processing record 48 ,set 6|itarema
# Processing record 49 ,set 6|tateyama
# Processing record 50 ,set 6|praia da vitoria
# Processing record 1 ,set 7|teahupoo
# Processing record 2 ,set 7|tsienyane
# City not found. Skipping...
# Processing record 3 ,set 7|bouar
# Processing record 4 ,set 7|vardo
# Processing record 5 ,set 7|morros
# Processing record 6 ,set 7|mogadishu
# Processing record 7 ,set 7|pisco
# Processing record 8 ,set 7|saint anthony
# Processing record 9 ,set 7|bandar-e lengeh
# Processing record 10 ,set 7|wagar
# Processing record 11 ,set 7|san patricio
# Processing record 12 ,set 7|byron bay
# Processing record 13 ,set 7|saldanha
# Processing record 14 ,set 7|mago
# Processing record 15 ,set 7|barsovo
# Processing record 16 ,set 7|rio cuarto
# Processing record 17 ,set 7|grand-santi
# Processing record 18 ,set 7|komsomolskiy
# Processing record 19 ,set 7|wanning
# Processing record 20 ,set 7|hambantota
# Processing record 21 ,set 7|san quintin
# Processing record 22 ,set 7|camacha
# Processing record 23 ,set 7|himora
# City not found. Skipping...
# Processing record 24 ,set 7|dakar
# Processing record 25 ,set 7|nzega
# Processing record 26 ,set 7|ierapetra
# Processing record 27 ,set 7|rorvik
# Processing record 28 ,set 7|vagur
# Processing record 29 ,set 7|marcona
# City not found. Skipping...
# Processing record 30 ,set 7|magadan
# Processing record 31 ,set 7|puerto quijarro
# Processing record 32 ,set 7|isangel
# Processing record 33 ,set 7|yumen
# Processing record 34 ,set 7|egvekinot
# Processing record 35 ,set 7|hay river
# Processing record 36 ,set 7|dolores
# Processing record 37 ,set 7|college
# Processing record 38 ,set 7|baneh
# Processing record 39 ,set 7|hofn
# Processing record 40 ,set 7|king city
# Processing record 41 ,set 7|katherine
# Processing record 42 ,set 7|oga
# Processing record 43 ,set 7|doka
# Processing record 44 ,set 7|quatre cocos
# Processing record 45 ,set 7|chokurdakh
# Processing record 46 ,set 7|amderma
# City not found. Skipping...
# Processing record 47 ,set 7|southbridge
# Processing record 48 ,set 7|prince rupert
# Processing record 49 ,set 7|yulara
# Processing record 50 ,set 7|curvelo
# Processing record 1 ,set 8|guadalajara
# Processing record 2 ,set 8|north providence
# Processing record 3 ,set 8|businga
# Processing record 4 ,set 8|along
# Processing record 5 ,set 8|scarborough
# Processing record 6 ,set 8|borogontsy
# Processing record 7 ,set 8|jumla
# Processing record 8 ,set 8|cortez
# Processing record 9 ,set 8|comodoro rivadavia
# Processing record 10 ,set 8|margate
# Processing record 11 ,set 8|ancud
# Processing record 12 ,set 8|mandiana
# Processing record 13 ,set 8|suao
# City not found. Skipping...
# Processing record 14 ,set 8|tautira
# Processing record 15 ,set 8|minot
# Processing record 16 ,set 8|pevek
# Processing record 17 ,set 8|altay
# Processing record 18 ,set 8|port lincoln
# City not found. Skipping...
# Processing record 19 ,set 8|lac-megantic
# Processing record 20 ,set 8|kardla
# Processing record 21 ,set 8|padang
# Processing record 22 ,set 8|gogapur
# Processing record 23 ,set 8|new castle
# Processing record 24 ,set 8|hornepayne
# Processing record 25 ,set 8|coquimbo
# Processing record 26 ,set 8|alice springs
# Processing record 27 ,set 8|palu
# Processing record 28 ,set 8|alexandria
# Processing record 29 ,set 8|surt
# Processing record 30 ,set 8|myitkyina
# Processing record 31 ,set 8|te anau
# Processing record 32 ,set 8|pedasi
# Processing record 33 ,set 8|asau
# Processing record 34 ,set 8|port hedland
# Processing record 35 ,set 8|denpasar
# Processing record 36 ,set 8|ajdabiya
# Processing record 37 ,set 8|shihezi
# Processing record 38 ,set 8|san cristobal
# Processing record 39 ,set 8|norman wells
# Processing record 40 ,set 8|moundou
# Processing record 41 ,set 8|kudahuvadhoo
# Processing record 42 ,set 8|tyup
# Processing record 43 ,set 8|abilene
# Processing record 44 ,set 8|darhan
# Processing record 45 ,set 8|longyan
# Processing record 46 ,set 8|ahipara
# Processing record 47 ,set 8|luanda
# Processing record 48 ,set 8|kostomuksha
# Processing record 49 ,set 8|farsund
# Processing record 50 ,set 8|general roca
# Processing record 1 ,set 9|goundam
# Processing record 2 ,set 9|maharajganj
# Processing record 3 ,set 9|terney
# Processing record 4 ,set 9|maridi
# Processing record 5 ,set 9|keti bandar
# Processing record 6 ,set 9|casino
# Processing record 7 ,set 9|halalo
# City not found. Skipping...
# Processing record 8 ,set 9|liberal
# Processing record 9 ,set 9|hasaki
# Processing record 10 ,set 9|port blair
# Processing record 11 ,set 9|fort nelson
# Processing record 12 ,set 9|san carlos de bariloche
# Processing record 13 ,set 9|albanel
# Processing record 14 ,set 9|togur
# Processing record 15 ,set 9|killarney
# Processing record 16 ,set 9|taicheng
# Processing record 17 ,set 9|duekoue
# Processing record 18 ,set 9|gobabis
# Processing record 19 ,set 9|flinders
# Processing record 20 ,set 9|leningradskiy
# Processing record 21 ,set 9|funchal
# Processing record 22 ,set 9|asosa
# Processing record 23 ,set 9|beringovskiy
# Processing record 24 ,set 9|houma
# Processing record 25 ,set 9|tanshui
# City not found. Skipping...
# Processing record 26 ,set 9|grand gaube
# Processing record 27 ,set 9|alanya
# Processing record 28 ,set 9|abu dhabi
# Processing record 29 ,set 9|kahului
# Processing record 30 ,set 9|beira
# Processing record 31 ,set 9|aksu
# Processing record 32 ,set 9|palenque
# Processing record 33 ,set 9|tasiilaq
# Processing record 34 ,set 9|formosa do rio preto
# Processing record 35 ,set 9|khorixas
# Processing record 36 ,set 9|sola
# Processing record 37 ,set 9|santiago
# Processing record 38 ,set 9|katete
# Processing record 39 ,set 9|formosa
# Processing record 40 ,set 9|sentyabrskiy
# City not found. Skipping...
# Processing record 41 ,set 9|jaisalmer
# Processing record 42 ,set 9|sur
# Processing record 43 ,set 9|glubokiy
# Processing record 44 ,set 9|sambava
# Processing record 45 ,set 9|suicheng
# Processing record 46 ,set 9|westport
# Processing record 47 ,set 9|bemidji
# Processing record 48 ,set 9|jiazi
# Processing record 49 ,set 9|port-cartier
# Processing record 50 ,set 9|saint-joseph
# Processing record 1 ,set 10|coatzintla
# Processing record 2 ,set 10|kissamos
# Processing record 3 ,set 10|makakilo city
# Processing record 4 ,set 10|coahuayana
# Processing record 5 ,set 10|bitkine
# Processing record 6 ,set 10|bolungarvik
# City not found. Skipping...
# Processing record 7 ,set 10|kamenskoye
# City not found. Skipping...
# Processing record 8 ,set 10|iracoubo
# Processing record 9 ,set 10|yerbogachen
# Processing record 10 ,set 10|okhotsk
# Processing record 11 ,set 10|la orilla
# Processing record 12 ,set 10|tahe
# Processing record 13 ,set 10|cuamba
# Processing record 14 ,set 10|hovd
# Processing record 15 ,set 10|mackay
# Processing record 16 ,set 10|kisangani
# Processing record 17 ,set 10|sept-iles
# Processing record 18 ,set 10|oksfjord
# Processing record 19 ,set 10|tommot
# Processing record 20 ,set 10|nemuro
# Processing record 21 ,set 10|yaan
# Processing record 22 ,set 10|karratha
# Processing record 23 ,set 10|hirtshals
# Processing record 24 ,set 10|les cayes
# Processing record 25 ,set 10|ayabaca
# Processing record 26 ,set 10|berlevag
# Processing record 27 ,set 10|labuhan
# Processing record 28 ,set 10|camana
# Processing record 29 ,set 10|launceston
# Processing record 30 ,set 10|ambatofinandrahana
# Processing record 31 ,set 10|takoradi
# Processing record 32 ,set 10|sitka
# Processing record 33 ,set 10|port hawkesbury
# Processing record 34 ,set 10|bubaque
# Processing record 35 ,set 10|kasempa
# Processing record 36 ,set 10|saint-augustin
# Processing record 37 ,set 10|novouzensk
# Processing record 38 ,set 10|mentok
# City not found. Skipping...
# Processing record 39 ,set 10|namibe
# Processing record 40 ,set 10|nome
# Processing record 41 ,set 10|tura
# Processing record 42 ,set 10|tromso
# Processing record 43 ,set 10|maryborough
# Processing record 44 ,set 10|iqaluit
# Processing record 45 ,set 10|waipawa
# Processing record 46 ,set 10|alotau
# City not found. Skipping...
# Processing record 47 ,set 10|yokadouma
# Processing record 48 ,set 10|la ronge
# Processing record 49 ,set 10|kapoeta
# Processing record 50 ,set 10|skibbereen
# Processing record 1 ,set 11|bose
# Processing record 2 ,set 11|kingaroy
# Processing record 3 ,set 11|richards bay
# Processing record 4 ,set 11|kragero
# Processing record 5 ,set 11|jejuri
# Processing record 6 ,set 11|saint-louis
# Processing record 7 ,set 11|veraval
# Processing record 8 ,set 11|gao
# Processing record 9 ,set 11|quelimane
# Processing record 10 ,set 11|bangolo
# Processing record 11 ,set 11|tocopilla
# Processing record 12 ,set 11|rabaul
# Processing record 13 ,set 11|goderich
# Processing record 14 ,set 11|dali
# Processing record 15 ,set 11|nouadhibou
# Processing record 16 ,set 11|la paz
# Processing record 17 ,set 11|reading
# Processing record 18 ,set 11|hihifo
# City not found. Skipping...
# Processing record 19 ,set 11|jacupiranga
# Processing record 20 ,set 11|mehamn
# Processing record 21 ,set 11|shimoda
# Processing record 22 ,set 11|darnah
# Processing record 23 ,set 11|mercedes
# Processing record 24 ,set 11|lazaro cardenas
# Processing record 25 ,set 11|khandyga
# Processing record 26 ,set 11|dahra
# Processing record 27 ,set 11|taburi
# City not found. Skipping...
# Processing record 28 ,set 11|sorong
# Processing record 29 ,set 11|alcoa
# Processing record 30 ,set 11|turukhansk
# Processing record 31 ,set 11|malatya
# Processing record 32 ,set 11|oktyabrskiy
# Processing record 33 ,set 11|kalaiya
# Processing record 34 ,set 11|havre-saint-pierre
# Processing record 35 ,set 11|hervey bay
# Processing record 36 ,set 11|henties bay
# Processing record 37 ,set 11|addi ugri
# City not found. Skipping...
# Processing record 38 ,set 11|olafsvik
# Processing record 39 ,set 11|mkushi
# Processing record 40 ,set 11|kiama
# Processing record 41 ,set 11|kalemie
# Processing record 42 ,set 11|zyryanka
# Processing record 43 ,set 11|bara
# Processing record 44 ,set 11|baglan
# Processing record 45 ,set 11|gamba
# Processing record 46 ,set 11|nizwa
# Processing record 47 ,set 11|marfino
# Processing record 48 ,set 11|hirara
# Processing record 49 ,set 11|genhe
# Processing record 50 ,set 11|lithgow
# Processing record 1 ,set 12|aldergrove
# Processing record 2 ,set 12|elat
# Processing record 3 ,set 12|hithadhoo
# Processing record 4 ,set 12|jiaojiang
# Processing record 5 ,set 12|udachnyy
# Processing record 6 ,set 12|najran
# Processing record 7 ,set 12|vao
# Processing record 8 ,set 12|mwinilunga
# Processing record 9 ,set 12|ugoofaaru
# Processing record 10 ,set 12|mantua
# Processing record 11 ,set 12|jiuquan
# Processing record 12 ,set 12|akdepe
# Processing record 13 ,set 12|indiaroba
# Processing record 14 ,set 12|yeniseysk
# Processing record 15 ,set 12|angren
# Processing record 16 ,set 12|sanford
# Processing record 17 ,set 12|moa
# Processing record 18 ,set 12|amapa
# Processing record 19 ,set 12|korla
# Processing record 20 ,set 12|hobyo
# Processing record 21 ,set 12|yar-sale
# Processing record 22 ,set 12|hami
# Processing record 23 ,set 12|zalantun
# Processing record 24 ,set 12|naze
# Processing record 25 ,set 12|bertoua
# Processing record 26 ,set 12|saint-pierre
# Processing record 27 ,set 12|samusu
# City not found. Skipping...
# Processing record 28 ,set 12|bayonet point
# Processing record 29 ,set 12|maceio
# Processing record 30 ,set 12|luba
# Processing record 31 ,set 12|naifaru
# Processing record 32 ,set 12|riyadh
# Processing record 33 ,set 12|thunder bay
# Processing record 34 ,set 12|mweka
# Processing record 35 ,set 12|zhucheng
# Processing record 36 ,set 12|kruisfontein
# Processing record 37 ,set 12|kushima
# Processing record 38 ,set 12|barra patuca
# Processing record 39 ,set 12|kidal
# Processing record 40 ,set 12|upata
# Processing record 41 ,set 12|puerto lleras
# Processing record 42 ,set 12|blagodarnyy
# Processing record 43 ,set 12|sakaraha
# Processing record 44 ,set 12|ust-kuyga
# Processing record 45 ,set 12|otane
# Processing record 46 ,set 12|biltine
# Processing record 47 ,set 12|nizhnyaya omka
# Processing record 48 ,set 12|vila franca do campo
# Processing record 49 ,set 12|ayorou
# Processing record 50 ,set 12|nsanje
# Processing record 1 ,set 13|palamos
# Processing record 2 ,set 13|general salgado
# Processing record 3 ,set 13|dallas
# Processing record 4 ,set 13|banfora
# Processing record 5 ,set 13|tual
# Processing record 6 ,set 13|romanovka
# Processing record 7 ,set 13|mocuba
# Processing record 8 ,set 13|ikryanoye
# Processing record 9 ,set 13|dongsheng
# Processing record 10 ,set 13|kangaatsiaq
# Processing record 11 ,set 13|coihaique
# Processing record 12 ,set 13|samana
# Processing record 13 ,set 13|nguru
# Processing record 14 ,set 13|yavaros
# Processing record 15 ,set 13|naantali
# Processing record 16 ,set 13|ilo
# Processing record 17 ,set 13|storslett
# Processing record 18 ,set 13|porto velho
# Processing record 19 ,set 13|great yarmouth
# Processing record 20 ,set 13|gimli
# Processing record 21 ,set 13|santa rosa
# Processing record 22 ,set 13|cerro largo
# Processing record 23 ,set 13|mumford
# Processing record 24 ,set 13|dukat
# Processing record 25 ,set 13|dzilam gonzalez
# Processing record 26 ,set 13|constantine
# Processing record 27 ,set 13|alpena
# Processing record 28 ,set 13|pinhal novo
# Processing record 29 ,set 13|slave lake
# Processing record 30 ,set 13|brandon
# Processing record 31 ,set 13|surovatikha
# Processing record 32 ,set 13|lima
# Processing record 33 ,set 13|jiexiu
# Processing record 34 ,set 13|anage
# Processing record 35 ,set 13|ruwi
# Processing record 36 ,set 13|stykkisholmur
# Processing record 37 ,set 13|muros
# Processing record 38 ,set 13|kapustin yar
# Processing record 39 ,set 13|terrace bay
# Processing record 40 ,set 13|kimbe
# Processing record 41 ,set 13|bereda
# Processing record 42 ,set 13|mokhsogollokh
# Processing record 43 ,set 13|havelock
# Processing record 44 ,set 13|vestmanna
# Processing record 45 ,set 13|dawan
# Processing record 46 ,set 13|saskatoon
# Processing record 47 ,set 13|awjilah
# Processing record 48 ,set 13|port hardy
# Processing record 49 ,set 13|kulhudhuffushi
# Processing record 50 ,set 13|campamento
# Processing record 1 ,set 14|batsfjord
# Processing record 2 ,set 14|lubumbashi
# Processing record 3 ,set 14|andevoranto
# City not found. Skipping...
# Processing record 4 ,set 14|praya
# Processing record 5 ,set 14|lata
# Processing record 6 ,set 14|white rock
# Processing record 7 ,set 14|afua
# Processing record 8 ,set 14|khilok
# Processing record 9 ,set 14|malwan
# City not found. Skipping...
# Processing record 10 ,set 14|lormi
# Processing record 11 ,set 14|roald
# Processing record 12 ,set 14|san vicente
# Processing record 13 ,set 14|qasigiannguit
# Processing record 14 ,set 14|picton
# Processing record 15 ,set 14|marion
# Processing record 16 ,set 14|cedar city
# Processing record 17 ,set 14|ewa beach
# Processing record 18 ,set 14|oranjemund
# Processing record 19 ,set 14|eyl
# Processing record 20 ,set 14|asyut
# Processing record 21 ,set 14|gigmoto
# Processing record 22 ,set 14|potchefstroom
# Processing record 23 ,set 14|cotonou
# Processing record 24 ,set 14|goya
# Processing record 25 ,set 14|ust-kamchatsk
# City not found. Skipping...
# Processing record 26 ,set 14|portland
# Processing record 27 ,set 14|mogochin
# City not found. Skipping...
# Processing record 28 ,set 14|la palma
# Processing record 29 ,set 14|sokoni
# Processing record 30 ,set 14|tecoanapa
# Processing record 31 ,set 14|sovetskiy
# Processing record 32 ,set 14|caravelas
# Processing record 33 ,set 14|juchitlan
# Processing record 34 ,set 14|fadd
# Processing record 35 ,set 14|lahaina
# Processing record 36 ,set 14|bafoulabe
# Processing record 37 ,set 14|bo phloi
# Processing record 38 ,set 14|lisakovsk
# Processing record 39 ,set 14|touros
# Processing record 40 ,set 14|north bend
# Processing record 41 ,set 14|kaoma
# Processing record 42 ,set 14|canico
# Processing record 43 ,set 14|trat
# Processing record 44 ,set 14|hermitage
# Processing record 45 ,set 14|pozzallo
# Processing record 46 ,set 14|thohoyandou
# Processing record 47 ,set 14|pestovo
# Processing record 48 ,set 14|brae
# Processing record 49 ,set 14|tungkang
# City not found. Skipping...
# Processing record 50 ,set 14|pekan
# Processing record 1 ,set 15|tevriz
# Processing record 2 ,set 15|agadez
# Processing record 3 ,set 15|nakhon thai
# Processing record 4 ,set 15|itapetinga
# Processing record 5 ,set 15|rudnaya pristan
# Processing record 6 ,set 15|chapada dos guimaraes
# Processing record 7 ,set 15|alofi
# Processing record 8 ,set 15|tsaotun
# City not found. Skipping...
# Processing record 9 ,set 15|chitradurga
# Processing record 10 ,set 15|durusu
# Processing record 11 ,set 15|saint-francois
# Processing record 12 ,set 15|tawkar
# City not found. Skipping...
# Processing record 13 ,set 15|svetlogorsk
# Processing record 14 ,set 15|gaoua
# Processing record 15 ,set 15|nova venecia
# Processing record 16 ,set 15|constitucion
# Processing record 17 ,set 15|nizhneyansk
# City not found. Skipping...
# Processing record 18 ,set 15|baykit
# Processing record 19 ,set 15|sigli
# Processing record 20 ,set 15|nouakchott
# Processing record 21 ,set 15|muswellbrook
# Processing record 22 ,set 15|moron
# Processing record 23 ,set 15|le port
# Processing record 24 ,set 15|balabac
# Processing record 25 ,set 15|nizhniy kuranakh
# Processing record 26 ,set 15|vanimo
# Processing record 27 ,set 15|hammerfest
# Processing record 28 ,set 15|kitimat
# Processing record 29 ,set 15|bugasong
# Processing record 30 ,set 15|haapu
# City not found. Skipping...
# Processing record 31 ,set 15|vicente guerrero
# Processing record 32 ,set 15|khonuu
# City not found. Skipping...
# Processing record 33 ,set 15|fengzhen
# Processing record 34 ,set 15|chatsu
# City not found. Skipping...
# Processing record 35 ,set 15|nisia floresta
# Processing record 36 ,set 15|urfa
# City not found. Skipping...
# Processing record 37 ,set 15|port-de-paix
# City not found. Skipping...
# Processing record 38 ,set 15|letka
# Processing record 39 ,set 15|gornji milanovac
# Processing record 40 ,set 15|bentiu
# Processing record 41 ,set 15|porto novo
# Processing record 42 ,set 15|algodones
# Processing record 43 ,set 15|paradise valley
# Processing record 44 ,set 15|basco
# Processing record 45 ,set 15|shawinigan
# Processing record 46 ,set 15|warrington
# Processing record 47 ,set 15|cabra
# Processing record 48 ,set 15|bay roberts
# Processing record 49 ,set 15|mvuma
# Processing record 50 ,set 15|hanzhong
# Processing record 1 ,set 16|cockburn harbour
# City not found. Skipping...
# Processing record 2 ,set 16|mattawa
# Processing record 3 ,set 16|shenxian
# Processing record 4 ,set 16|mauguio
# Processing record 5 ,set 16|waterloo
# Processing record 6 ,set 16|kirakira
# Processing record 7 ,set 16|great bend
# Processing record 8 ,set 16|alekseyevsk
# Processing record 9 ,set 16|port macquarie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the dictionary to a DF
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande  38.5167  -28.7000     59.16        65          85
# 1         Halifax  44.6453  -63.5724     52.29        93         100
# 2         Rikitea -23.1203 -134.9692     77.50        81           9
# 3          Shingu  33.7333  135.9833     64.44        91         100
# 4          Viedma -40.8135  -62.9967     54.93        59         100
#
#    Wind Speed Country Current Description
# 0       15.05      PT     overcast clouds
# 1        6.91      CA                mist
# 2       20.29      PF           clear sky
# 3        7.67      JP     overcast clouds
# 4       11.50      AR     overcast clouds

# %%
new_col_order=['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df=city_data_df[new_col_order]
city_data_df.head(15)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Ribeira Grande      PT  38.5167  -28.7000     59.16        65          85
# 1          Halifax      CA  44.6453  -63.5724     52.29        93         100
# 2          Rikitea      PF -23.1203 -134.9692     77.50        81           9
# 3           Shingu      JP  33.7333  135.9833     64.44        91         100
# 4           Viedma      AR -40.8135  -62.9967     54.93        59         100
# 5         Radcliff      US  37.8404  -85.9491     89.98        54          20
# 6          Csenger      HU  47.8358   22.6810     59.05        72          99
# 7             Jalu      LY  29.0331   21.5482     73.13        44         100
# 8            Bluff      NZ -46.6000  168.3333     51.80        81          17
# 9            Seoul      KR  37.5683  126.9778     54.84        62         100
# 10         Jagtial      IN  18.8000   78.9333     87.80        55         100
# 11         Ushuaia      AR -54.8000  -68.3000     49.66        57          75
# 12       Upernavik      GL  72.7868  -56.1549     22.64        81          89
# 13        Souillac      MU -20.5167   57.5167     74.25        86           0
# 14          Maitum      PH   6.0392  124.4986     79.45        83          98
#
#     Wind Speed Current Description
# 0        15.05     overcast clouds
# 1         6.91                mist
# 2        20.29           clear sky
# 3         7.67     overcast clouds
# 4        11.50     overcast clouds
# 5         8.05          few clouds
# 6         4.90     overcast clouds
# 7        15.19          light rain
# 8        15.61          few clouds
# 9         2.53     overcast clouds
# 10        9.28     overcast clouds
# 11       18.41       broken clouds
# 12        7.16     overcast clouds
# 13        4.92           clear sky
# 14        3.78     overcast clouds

# %%
csv_file=city_data_df.to_csv('WeatherPy_Database.csv')
